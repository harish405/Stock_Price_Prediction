# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings ("ignore")

# %%
#reading dataset
df=pd.read_csv("/content/NFLX.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['Open'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['High'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_3, *['Low'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['Open'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_6, *['High'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_7, *['Low'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_8, *['Date'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_9, *[[['index', 'Open'], ['Open', 'High'], ['High', 'Low'], ['Low', 'Close']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_10, *['index', 'Date'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_11, *['Open', 'Date'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_12, *['High', 'Date'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_13, *['Low', 'Date'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_14, *['index', 'Open', 'Date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_15, *['index', 'High', 'Date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_16, *['index', 'Low', 'Date'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_17, *['index', 'Close', 'Date'], **{})
# chart

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2022-01-31  20047500
# 2022-02-01  22542300
# 2022-02-02  14346000
# 2022-02-03   9905200
# 2022-02-04   7782400

# %%
cls = df[['Close']]
cls.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1=cls.values
df1
# Out:
# array([[254.259995],
#        [265.720001],
#        [264.559998],
#        ...,
#        [429.480011],
#        [405.600006],
#        [410.170013]])

# %%
df1.shape
# Out:
# (1009, 1)

# %%
#plotting the data
plt.figure(figsize=(10, 5))
plt.plot(df1)

# %%
#scalling the data
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1
# Out:
# array([[0.04451626],
#        [0.06954849],
#        [0.06701469],
#        ...,
#        [0.4272515 ],
#        [0.37509011],
#        [0.38507243]])

# %%
len(df1)
# Out:
# 1009

# %%
#Defining test and train data sizes
train_size = int(len(df1)*0.80)
test_size = len(df1) - train_size

# %%
train_size,test_size
# Out:
# (807, 202)

# %%
#Splitting data between train and test
train, test = df1[0:train_size,:], df1[train_size:len(df1),:1]

# %%
len(train),len(test)
# Out:
# (807, 202)

# %%
#creating dataset matrix for LSTM model

def create_df(dataset,step):
    X, y = [], []
    for i in range(len(dataset)-step-1):
        ds = dataset[i:(i+step), 0]
        X.append(ds)
        y.append(dataset[i + step, 0])
    return np.array(X), np.array(y)

# %%
#Taking 100 days price as one record for training
time_stamp = 100
X_train, y_train = create_df(train,time_stamp)
X_test, y_test = create_df(test,time_stamp)

# %%
X_train.shape,y_train.shape
# Out:
# ((706, 100), (706,))

# %%
X_test.shape, y_test.shape
# Out:
# ((101, 100), (101,))

# %%
#Reshaping data to fit into LSTM model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
#importing libraries for lstm model
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
#Creating LSTM model using keras
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(LSTM(units=50,return_sequences=True))
model.add(LSTM(units=50))
model.add(Dense(units=1,activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Training model with adam optimizer and mean squared error loss function
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=128)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 10s 496ms/step - loss: 0.1106 - val_loss: 0.0292
# Epoch 2/100
# 6/6 [==============================] - 2s 257ms/step - loss: 0.0175 - val_loss: 0.0456
# Epoch 3/100
# 6/6 [==============================] - 2s 262ms/step - loss: 0.0117 - val_loss: 0.0712
# Epoch 4/100
# 6/6 [==============================] - 1s 244ms/step - loss: 0.0072 - val_loss: 0.0172
# Epoch 5/100
# 6/6 [==============================] - 1s 252ms/step - loss: 0.0064 - val_loss: 0.0207
# Epoch 6/100
# 6/6 [==============================] - 2s 416ms/step - loss: 0.0044 - val_loss: 0.0187
# Epoch 7/100
# 6/6 [==============================] - 2s 276ms/step - loss: 0.0031 - val_loss: 0.0183
# Epoch 8/100
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0031 - val_loss: 0.0148
# Epoch 9/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0031 - val_loss: 0.0160
# Epoch 10/100
# 6/6 [==============================] - 2s 254ms/step - loss: 0.0030 - val_loss: 0.0156
# Epoch 11/100
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0028 - val_loss: 0.0144
# Epoch 12/100
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0028 - val_loss: 0.0146
# Epoch 13/100
# 6/6 [==============================] - 2s 258ms/step - loss: 0.0028 - val_loss: 0.0141
# Epoch 14/100
# 6/6 [==============================] - 2s 409ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 15/100
# 6/6 [==============================] - 2s 246ms/step - loss: 0.0028 - val_loss: 0.0142
# Epoch 16/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0028 - val_loss: 0.0135
# Epoch 17/100
# 6/6 [==============================] - 1s 247ms/step - loss: 0.0027 - val_loss: 0.0136
# Epoch 18/100
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0027 - val_loss: 0.0133
# Epoch 19/100
# 6/6 [==============================] - 2s 268ms/step - loss: 0.0026 - val_loss: 0.0130
# Epoch 20/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0026 - val_loss: 0.0127
# Epoch 21/100
# 6/6 [==============================] - 2s 283ms/step - loss: 0.0026 - val_loss: 0.0122
# Epoch 22/100
# 6/6 [==============================] - 2s 409ms/step - loss: 0.0026 - val_loss: 0.0130
# Epoch 23/100
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0026 - val_loss: 0.0116
# Epoch 24/100
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0025 - val_loss: 0.0119
# Epoch 25/100
# 6/6 [==============================] - 2s 384ms/step - loss: 0.0025 - val_loss: 0.0112
# Epoch 26/100
# 6/6 [==============================] - 2s 331ms/step - loss: 0.0025 - val_loss: 0.0112
# Epoch 27/100
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0025 - val_loss: 0.0107
# Epoch 28/100
# 6/6 [==============================] - 2s 261ms/step - loss: 0.0024 - val_loss: 0.0101
# Epoch 29/100
# 6/6 [==============================] - 2s 409ms/step - loss: 0.0024 - val_loss: 0.0109
# Epoch 30/100
# 6/6 [==============================] - 2s 346ms/step - loss: 0.0024 - val_loss: 0.0096
# Epoch 31/100
# 6/6 [==============================] - 2s 396ms/step - loss: 0.0023 - val_loss: 0.0094
# Epoch 32/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 33/100
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0024 - val_loss: 0.0110
# Epoch 34/100
# 6/6 [==============================] - 3s 445ms/step - loss: 0.0024 - val_loss: 0.0095
# Epoch 35/100
# 6/6 [==============================] - 2s 394ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 36/100
# 6/6 [==============================] - 2s 316ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 37/100
# 6/6 [==============================] - 2s 257ms/step - loss: 0.0023 - val_loss: 0.0113
# Epoch 38/100
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0024 - val_loss: 0.0089
# Epoch 39/100
# 6/6 [==============================] - 1s 252ms/step - loss: 0.0024 - val_loss: 0.0095
# Epoch 40/100
# 6/6 [==============================] - 2s 255ms/step - loss: 0.0025 - val_loss: 0.0085
# Epoch 41/100
# 6/6 [==============================] - 2s 254ms/step - loss: 0.0022 - val_loss: 0.0109
# Epoch 42/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0022 - val_loss: 0.0081
# Epoch 43/100
# 6/6 [==============================] - 2s 411ms/step - loss: 0.0021 - val_loss: 0.0079
# Epoch 44/100
# 6/6 [==============================] - 2s 283ms/step - loss: 0.0020 - val_loss: 0.0083
# Epoch 45/100
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 46/100
# 6/6 [==============================] - 1s 248ms/step - loss: 0.0021 - val_loss: 0.0076
# Epoch 47/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0019 - val_loss: 0.0075
# Epoch 48/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0019 - val_loss: 0.0077
# Epoch 49/100
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0018 - val_loss: 0.0082
# Epoch 50/100
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0019 - val_loss: 0.0075
# Epoch 51/100
# 6/6 [==============================] - 3s 423ms/step - loss: 0.0018 - val_loss: 0.0076
# Epoch 52/100
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0019 - val_loss: 0.0072
# Epoch 53/100
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0018 - val_loss: 0.0081
# Epoch 54/100
# 6/6 [==============================] - 1s 241ms/step - loss: 0.0018 - val_loss: 0.0077
# Epoch 55/100
# 6/6 [==============================] - 1s 252ms/step - loss: 0.0019 - val_loss: 0.0072
# Epoch 56/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0018 - val_loss: 0.0069
# Epoch 57/100
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0018 - val_loss: 0.0079
# Epoch 58/100
# 6/6 [==============================] - 2s 295ms/step - loss: 0.0017 - val_loss: 0.0073
# Epoch 59/100
# 6/6 [==============================] - 2s 409ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 60/100
# 6/6 [==============================] - 2s 250ms/step - loss: 0.0017 - val_loss: 0.0068
# Epoch 61/100
# 6/6 [==============================] - 2s 254ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 62/100
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 63/100
# 6/6 [==============================] - 2s 251ms/step - loss: 0.0016 - val_loss: 0.0067
# Epoch 64/100
# 6/6 [==============================] - 1s 250ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 65/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 66/100
# 6/6 [==============================] - 2s 308ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 67/100
# 6/6 [==============================] - 2s 415ms/step - loss: 0.0015 - val_loss: 0.0063
# Epoch 68/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0015 - val_loss: 0.0062
# Epoch 69/100
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0015 - val_loss: 0.0062
# Epoch 70/100
# 6/6 [==============================] - 2s 257ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 71/100
# 6/6 [==============================] - 2s 251ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 72/100
# 6/6 [==============================] - 1s 248ms/step - loss: 0.0014 - val_loss: 0.0070
# Epoch 73/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 74/100
# 6/6 [==============================] - 2s 328ms/step - loss: 0.0014 - val_loss: 0.0062
# Epoch 75/100
# 6/6 [==============================] - 2s 377ms/step - loss: 0.0014 - val_loss: 0.0074
# Epoch 76/100
# 6/6 [==============================] - 2s 254ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 77/100
# 6/6 [==============================] - 1s 252ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 78/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 79/100
# 6/6 [==============================] - 2s 255ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 80/100
# 6/6 [==============================] - 1s 247ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 81/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 82/100
# 6/6 [==============================] - 2s 369ms/step - loss: 0.0014 - val_loss: 0.0054
# Epoch 83/100
# 6/6 [==============================] - 2s 349ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 84/100
# 6/6 [==============================] - 1s 247ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 85/100
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 86/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 87/100
# 6/6 [==============================] - 2s 255ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 88/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 89/100
# 6/6 [==============================] - 2s 249ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 90/100
# 6/6 [==============================] - 2s 369ms/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 91/100
# 6/6 [==============================] - 2s 333ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 92/100
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 93/100
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 94/100
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 95/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 96/100
# 6/6 [==============================] - 1s 251ms/step - loss: 0.0011 - val_loss: 0.0046
# Epoch 97/100
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 98/100
# 6/6 [==============================] - 2s 387ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 99/100
# 6/6 [==============================] - 2s 328ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 100/100
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0011 - val_loss: 0.0042

# %%
#PLotting loss, it shows that loss has decreased significantly and model trained well
loss = model.history.history['loss']
plt.plot(loss)

# %%
#Predicitng on train and test data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 23/23 [==============================] - 2s 37ms/step
# 4/4 [==============================] - 0s 34ms/step

# %%
#Inverse transformation to get actual value
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
#Comparing using data visualization
plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(df1))
plt.plot(train_predict)
plt.plot(test_predict)

# %%
test = np.vstack((train_predict,test_predict))

# %%
#Combining the predited data to create uniform data visualization
plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(df1))
plt.plot(test)

# %%
len(test)
# Out:
# 807

# %%
#Getting the last 100 days records
fut_inp = test[707:]
fut_inp = fut_inp.reshape(1,-1)
fut_inp.shape
# Out:
# (1, 100)

# %%
tmp_inp = list(fut_inp)

# %%
#Creating list of the last 100 data
tmp_inp = tmp_inp[0].tolist()

# %%
#Predicting next 30 days price suing the current data
#It will predict in sliding window manner (algorithm) with stride 1
lst_output=[]
n_steps=100
i=0
while(i<30):

    if(len(tmp_inp)>100):
        fut_inp = np.array(tmp_inp[1:])
        fut_inp=fut_inp.reshape(1,-1)
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        tmp_inp = tmp_inp[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        fut_inp = fut_inp.reshape((1, n_steps,1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1


print(lst_output)
# Out:
# [[2.8198978900909424], [2.609119415283203], [2.357079029083252], [2.1132266521453857], [1.8918132781982422], [1.703795075416565], [1.558003544807434], [1.4578520059585571], [1.4009953737258911], [1.3809435367584229], [1.3888163566589355], [1.414183259010315], [1.4458295106887817], [1.4735301733016968], [1.4899338483810425], [1.4914435148239136], [1.4781802892684937], [1.4532489776611328], [1.4213206768035889], [1.3869940042495728], [1.3536919355392456], [1.3233963251113892], [1.2969321012496948], [1.2743839025497437], [1.255462408065796], [1.2397692203521729], [1.2269847393035889], [1.2169592380523682], [1.2097076177597046], [1.2053041458129883]]

# %%
len(df1)
# Out:
# 1009

# %%
#Creating a dummy plane to plot graph one after another
plot_new=np.arange(1,101)
plot_pred=np.arange(101,131)

# %%
#plt.figure(figsize=(10, 5))
plt.plot(plot_new, scaler.inverse_transform(df1[909:]))
plt.plot(plot_pred, scaler.inverse_transform(lst_output))

# %%
ds_new = df1.tolist()

# %%
len(ds_new)
# Out:
# 1009

# %%
#filling the missing value with approx value
plt.figure(figsize=(10, 5))
ds_new.extend(lst_output)
plt.plot(ds_new[909:])

# %%
#Creating final data for plotting
final_graph = scaler.inverse_transform(ds_new).tolist()

# %%
#Plotting final results with predicted value after 30 Days
plt.figure(figsize=(10, 5))
plt.plot(final_graph,)
plt.ylabel("Price")
plt.xlabel("Time")
plt.title("Netflix prediction of next month close")
plt.axhline(y=final_graph[len(final_graph)-1], color = 'red', linestyle = ':', label = 'NEXT 30D: {0}'.format(round(float(*final_graph[len(final_graph)-1]),2)))
plt.legend()
